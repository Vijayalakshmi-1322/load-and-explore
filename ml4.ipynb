# %%
import pandas as pd
csv_file_path='C:\ML_Project directory\\sample_data.csv'
excel_file_path='C:\ML_Project directory\\sample_data.xlsx'

data_csv=pd.read_csv(csv_file_path)
print("csv file data:")
print(data_csv)

data_excel=pd.read_excel(excel_file_path)
print(data_excel)

print("\n Data Description:")
print("csv Data Description:")
print(data_csv.describe())

print("\n Excel Data Descriptions:")
print(data_excel.describe())

print("\n Data Types in csv file:")
print(data_csv.dtypes)


print("\n Data Types in Excel file:")
print(data_excel.dtypes)
# Out:
# csv file data:
#          Nme  Age  Score
# 0  Vinodhini   20    100
# 1     Swathi   26     99
# 2   Chethana    8     77
#       Name Category  Numbers Of Animals/Birds
# 0     Dogs   Animal                         2
# 1     Cats   Animal                         3
# 2  Parrots     Bird                         4
# 3  Pigeons     Bird                         1
# 4   Dove's     Bird                         2
#
#  Data Description:
# csv Data Description:
#              Age  Score
# count   3.000000    3.0
# mean   18.000000   92.0
# std     9.165151   13.0
# min     8.000000   77.0
# 25%    14.000000   88.0
# 50%    20.000000   99.0
# 75%    23.000000   99.5
# max    26.000000  100.0
#
#  Excel Data Descriptions:
#        Numbers Of Animals/Birds
# count                  5.000000
# mean                   2.400000
# std                    1.140175
# min                    1.000000
# 25%                    2.000000
# 50%                    2.000000
# 75%                    3.000000
# max                    4.000000
#
#  Data Types in csv file:
# Nme      object
# Age       int64
# Score     int64
# dtype: object
#
#  Data Types in Excel file:
# Name                        object
# Category                    object
# Numbers Of Animals/Birds     int64
# dtype: object

# %%
import pandas as pd
csv_file_path='C:\ML_Project directory\\animals.csv'
excel_file_path='C:\ML_Project directory\\trees.xlsx'

data_csv=pd.read_csv(csv_file_path)
print("csv file data:")
print(data_csv)

data_excel=pd.read_excel(excel_file_path)
print(data_excel)

print("Dataset information:")
print(data_csv.info())

print("\n First few rows of the dataset:")
print(data_csv.head())

print("\n Summary statistics:")
print(data_csv.describe())

print("\n Data Description:")
print("csv Data Description:")
print(data_csv.describe())

print("\n Excel Data Descriptions:")
print(data_excel.describe())

print("\n Data Types in csv file:")
print(data_csv.dtypes)


print("\n Data Types in Excel file:")
print(data_excel.dtypes)
